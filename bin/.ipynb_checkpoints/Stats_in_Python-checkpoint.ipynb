# %% [markdown]
# I would like to ask the question of "Is there a connection between the depth of an earthquake and it's magnitude?"

# %%
## import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#stats libraries
import statsmodels.api as sm
import scipy

#allows us to show plots in notebook
# %matplotlib inline

# %%
filename = '../data/SHEEF2010.txt' #created a variable that it would be easy to call

sheef = pd.read_csv(filename, sep = '\s+', header=1, index_col='Date')
#made dataframe into variable sheef, deleted unnecessary header, changed the index
sheef.max
sheef.head()
# Out:
#                MW  Longitude  Latitude Source  Depth   DF    OM   OMT  MW2
# Date
# 162701010000  3.4     -70.80      42.6    NCE      0  3.8  MbLg  3.37  NaN
# 163806111900  6.5     -71.80      44.4    Ebe      0  6.5  MbLg  6.46  NaN
# 163807010000  2.4     -70.90      42.5    NCE      0  2.7  MbLg  2.36  NaN
# 163901250000  2.4     -70.95      42.5    NCE      0  2.7  MbLg  2.36  NaN
# 164303151200  2.9     -70.80      42.8    NCE      0  3.3  MbLg  2.90  NaN

# %% [markdown]
# comment by nick
#
# i changed the path way when loading your data. this was simply because your data was not in the right place after moving the assigment in to the new directory. I also removed the print function to create a table wiht pandas and added head to limit what data is being show in the table. this doesnt mean the data is not loaded but simply makes it easier for me to scroll through the assignment.

# %%
#seperated the two variables I wanted to statistically check. Created a new dataframe called mag_depth.

mag_depth = sheef[['MW', 'Depth']]
mag_depth.head()
# Out:
#                MW  Depth
# Date
# 162701010000  3.4      0
# 163806111900  6.5      0
# 163807010000  2.4      0
# 163901250000  2.4      0
# 164303151200  2.9      0

# %%
#Plotted the data from the two variables to see what they look like.

mag_depth.plot(kind ='scatter', x='Depth', y='MW', color='#FF7272', figsize=(13,10))
plt.xlim(1.5, 9.5)
plt.ylim(0, 10)
# Out:
# (0, 10)
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# comment by nick
#
# why did you limit the x axis? the range goes to 300 km in depth.

# %%
#statistics thing!
lm = sm.formula.ols(formula='MW ~ Depth', data = mag_depth).fit()

# %%
#more statistics things
lm.params
# Out:
# Intercept    2.938521
# Depth        0.012186
# dtype: float64

# %%
#created a new dataframe to create x values that will help produce a linar line of best fit.
d_new = pd.DataFrame({'Depth' : range(0, 300)})

# %% [markdown]
# comment by nick
#
# here i just added more numbers to your range changing it from 100 to 300. this will make your line in the graph longer and show clearly that it doesnt fallow a trend.

# %%
d_new.head()
# Out:
#    Depth
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4

# %%
#This is going to help with the linear regression line I think
y_preds = lm.predict(d_new)
#removed the line that shows the aray of numbers.

# %%
#checked the histogram to see if the data looks weird. It kinda does.
mag_depth.hist(column='MW', bins = 50, figsize=(13, 8))
plt.show()

# %%
#added the statistical information to the scatter plot. The line doesn't match anything at all...
mag_depth.plot(kind='scatter', x='Depth', y='MW', color='c', figsize = (14, 8))
#plt.xlim(0, 70)
#plt.ylim(0, 0.3)

plt.plot(d_new, y_preds, color='red', linewidth=3)
# Out:
# //anaconda/lib/python3.4/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %%
#printed a summary of the statistical analysis to see what the numbers are saying.
print (lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     MW   R-squared:                       0.088
# Model:                            OLS   Adj. R-squared:                  0.088
# Method:                 Least Squares   F-statistic:                     4003.
# Date:                Mon, 09 Nov 2015   Prob (F-statistic):               0.00
# Time:                        21:10:47   Log-Likelihood:                -51974.
# No. Observations:               41690   AIC:                         1.040e+05
# Df Residuals:                   41688   BIC:                         1.040e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------
# Intercept      2.9385      0.005    554.968      0.000         2.928     2.949
# Depth          0.0122      0.000     63.270      0.000         0.012     0.013
# ==============================================================================
# Omnibus:                     6461.970   Durbin-Watson:                   1.450
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            11114.729
# Skew:                           1.022   Prob(JB):                         0.00
# Kurtosis:                       4.489   Cond. No.                         35.3
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# Given the absolute lack of any kind of signs that there is a conenction between depth and magnitude, this data leads me to believe there is no connection. The R-squared value is very close to 0%. Also, the probability is 0. Therefore, we learned there isnt a connection in this data set between the depth of an earthquake and its magnitude.

# %% [markdown]
# comment by nick
#
# the relationship between depth and magnatiude may not be linar. I had a very simular problem with my data and im presently teaching myself how to find other types of relationships between variables. Once i figure it out ill let you know how its done and you can try it for your self.
